# %%
# !git clone https://github.com/ok1zjf/VASNet.git

# %%
cd VASNet

# %%
# !python create_split.py -d "C:\Users\pool5.h5" --save-dir splits --save-name tvsum_splits --num-splits 5

# %%
# !python main.py --train
