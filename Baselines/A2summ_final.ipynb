# %%
# !pip3 install torch==1.12.0+cu113 torchvision==0.13.0+cu113 --extra-index-url https://download.pytorch.org/whl/cu113
# !pip3 install tensorboard
# !pip3 install rouge-score==0.1.2
# !pip3 install scipy ortools h5py pyyaml

# %%
# download A2Summ repository in local system and save SMI-CVD dataset processed in .h5 along with summe and TVSum

# %%
cd A2Summ

# %%
pwd

# %%
# !python train.py --dataset SMI_CVD
